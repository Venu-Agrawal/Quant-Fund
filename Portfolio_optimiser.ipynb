# %%
#installing all the necessary libraries
# !pip install yfinance
# !pip install quantstats
# !pip install catboost
# !pip install xgboost
# !pip install lightgbm
# !pip install pmdarima
# !pip install pyPortfolioOpt
# Out:
# Requirement already satisfied: yfinance in c:\python\python311\lib\site-packages (0.2.25)
# Requirement already satisfied: pandas>=1.3.0 in c:\python\python311\lib\site-packages (from yfinance) (2.0.3)
# Requirement already satisfied: numpy>=1.16.5 in c:\python\python311\lib\site-packages (from yfinance) (1.25.1)
# Requirement already satisfied: requests>=2.26 in c:\python\python311\lib\site-packages (from yfinance) (2.31.0)
# Requirement already satisfied: multitasking>=0.0.7 in c:\python\python311\lib\site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: lxml>=4.9.1 in c:\python\python311\lib\site-packages (from yfinance) (4.9.3)
# Requirement already satisfied: appdirs>=1.4.4 in c:\python\python311\lib\site-packages (from yfinance) (1.4.4)
# Requirement already satisfied: pytz>=2022.5 in c:\python\python311\lib\site-packages (from yfinance) (2023.3)
# Requirement already satisfied: frozendict>=2.3.4 in c:\python\python311\lib\site-packages (from yfinance) (2.3.8)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\python\python311\lib\site-packages (from yfinance) (4.12.2)
# Requirement already satisfied: html5lib>=1.1 in c:\python\python311\lib\site-packages (from yfinance) (1.1)
# Requirement already satisfied: soupsieve>1.2 in c:\python\python311\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.4.1)
# Requirement already satisfied: six>=1.9 in c:\python\python311\lib\site-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: webencodings in c:\python\python311\lib\site-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\python\python311\lib\site-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: tzdata>=2022.1 in c:\python\python311\lib\site-packages (from pandas>=1.3.0->yfinance) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\python\python311\lib\site-packages (from requests>=2.26->yfinance) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\python\python311\lib\site-packages (from requests>=2.26->yfinance) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\python\python311\lib\site-packages (from requests>=2.26->yfinance) (2.0.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\python\python311\lib\site-packages (from requests>=2.26->yfinance) (2023.5.7)
# [notice] A new release of pip is available: 23.2.1 -> 23.3.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: quantstats in c:\python\python311\lib\site-packages (0.0.62)
# Requirement already satisfied: pandas>=0.24.0 in c:\python\python311\lib\site-packages (from quantstats) (2.0.3)
# Requirement already satisfied: numpy>=1.16.5 in c:\python\python311\lib\site-packages (from quantstats) (1.25.1)
# Requirement already satisfied: seaborn>=0.9.0 in c:\python\python311\lib\site-packages (from quantstats) (0.12.2)
# Requirement already satisfied: matplotlib>=3.0.0 in c:\python\python311\lib\site-packages (from quantstats) (3.7.2)
# Requirement already satisfied: scipy>=1.2.0 in c:\python\python311\lib\site-packages (from quantstats) (1.11.1)
# Requirement already satisfied: tabulate>=0.8.0 in c:\python\python311\lib\site-packages (from quantstats) (0.9.0)
# Requirement already satisfied: yfinance>=0.1.70 in c:\python\python311\lib\site-packages (from quantstats) (0.2.25)
# Requirement already satisfied: python-dateutil>=2.0 in c:\python\python311\lib\site-packages (from quantstats) (2.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\python\python311\lib\site-packages (from matplotlib>=3.0.0->quantstats) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in c:\python\python311\lib\site-packages (from matplotlib>=3.0.0->quantstats) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\python\python311\lib\site-packages (from matplotlib>=3.0.0->quantstats) (4.42.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\python\python311\lib\site-packages (from matplotlib>=3.0.0->quantstats) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\python\python311\lib\site-packages (from matplotlib>=3.0.0->quantstats) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\python\python311\lib\site-packages (from matplotlib>=3.0.0->quantstats) (10.0.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\python\python311\lib\site-packages (from matplotlib>=3.0.0->quantstats) (3.0.9)
# Requirement already satisfied: pytz>=2020.1 in c:\python\python311\lib\site-packages (from pandas>=0.24.0->quantstats) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in c:\python\python311\lib\site-packages (from pandas>=0.24.0->quantstats) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\python\python311\lib\site-packages (from python-dateutil>=2.0->quantstats) (1.16.0)
# Requirement already satisfied: requests>=2.26 in c:\python\python311\lib\site-packages (from yfinance>=0.1.70->quantstats) (2.31.0)
# Requirement already satisfied: multitasking>=0.0.7 in c:\python\python311\lib\site-packages (from yfinance>=0.1.70->quantstats) (0.0.11)
# Requirement already satisfied: lxml>=4.9.1 in c:\python\python311\lib\site-packages (from yfinance>=0.1.70->quantstats) (4.9.3)
# Requirement already satisfied: appdirs>=1.4.4 in c:\python\python311\lib\site-packages (from yfinance>=0.1.70->quantstats) (1.4.4)
# Requirement already satisfied: frozendict>=2.3.4 in c:\python\python311\lib\site-packages (from yfinance>=0.1.70->quantstats) (2.3.8)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\python\python311\lib\site-packages (from yfinance>=0.1.70->quantstats) (4.12.2)
# Requirement already satisfied: html5lib>=1.1 in c:\python\python311\lib\site-packages (from yfinance>=0.1.70->quantstats) (1.1)
# Requirement already satisfied: soupsieve>1.2 in c:\python\python311\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance>=0.1.70->quantstats) (2.4.1)
# Requirement already satisfied: webencodings in c:\python\python311\lib\site-packages (from html5lib>=1.1->yfinance>=0.1.70->quantstats) (0.5.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\python\python311\lib\site-packages (from requests>=2.26->yfinance>=0.1.70->quantstats) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\python\python311\lib\site-packages (from requests>=2.26->yfinance>=0.1.70->quantstats) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\python\python311\lib\site-packages (from requests>=2.26->yfinance>=0.1.70->quantstats) (2.0.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\python\python311\lib\site-packages (from requests>=2.26->yfinance>=0.1.70->quantstats) (2023.5.7)
# [notice] A new release of pip is available: 23.2.1 -> 23.3.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: catboost in c:\python\python311\lib\site-packages (1.2.2)
# Requirement already satisfied: graphviz in c:\python\python311\lib\site-packages (from catboost) (0.20.1)
# Requirement already satisfied: matplotlib in c:\python\python311\lib\site-packages (from catboost) (3.7.2)
# Requirement already satisfied: numpy>=1.16.0 in c:\python\python311\lib\site-packages (from catboost) (1.25.1)
# Requirement already satisfied: pandas>=0.24 in c:\python\python311\lib\site-packages (from catboost) (2.0.3)
# Requirement already satisfied: scipy in c:\python\python311\lib\site-packages (from catboost) (1.11.1)
# Requirement already satisfied: plotly in c:\python\python311\lib\site-packages (from catboost) (5.15.0)
# Requirement already satisfied: six in c:\python\python311\lib\site-packages (from catboost) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\python\python311\lib\site-packages (from pandas>=0.24->catboost) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\python\python311\lib\site-packages (from pandas>=0.24->catboost) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in c:\python\python311\lib\site-packages (from pandas>=0.24->catboost) (2023.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\python\python311\lib\site-packages (from matplotlib->catboost) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in c:\python\python311\lib\site-packages (from matplotlib->catboost) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\python\python311\lib\site-packages (from matplotlib->catboost) (4.42.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\python\python311\lib\site-packages (from matplotlib->catboost) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\python\python311\lib\site-packages (from matplotlib->catboost) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\python\python311\lib\site-packages (from matplotlib->catboost) (10.0.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\python\python311\lib\site-packages (from matplotlib->catboost) (3.0.9)
# Requirement already satisfied: tenacity>=6.2.0 in c:\python\python311\lib\site-packages (from plotly->catboost) (8.2.2)
# [notice] A new release of pip is available: 23.2.1 -> 23.3.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: xgboost in c:\python\python311\lib\site-packages (2.0.1)
# Requirement already satisfied: numpy in c:\python\python311\lib\site-packages (from xgboost) (1.25.1)
# Requirement already satisfied: scipy in c:\python\python311\lib\site-packages (from xgboost) (1.11.1)
# [notice] A new release of pip is available: 23.2.1 -> 23.3.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: lightgbm in c:\python\python311\lib\site-packages (4.1.0)
# [notice] A new release of pip is available: 23.2.1 -> 23.3.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: numpy in c:\python\python311\lib\site-packages (from lightgbm) (1.25.1)
# Requirement already satisfied: scipy in c:\python\python311\lib\site-packages (from lightgbm) (1.11.1)
# Collecting pmdarima
#   Obtaining dependency information for pmdarima from https://files.pythonhosted.org/packages/ac/f8/6c9364602b13f0dba129b53acd1344859690911a4d5021560d9fd6aa087f/pmdarima-2.0.4-cp311-cp311-win_amd64.whl.metadata
#   Downloading pmdarima-2.0.4-cp311-cp311-win_amd64.whl.metadata (8.0 kB)
# Requirement already satisfied: joblib>=0.11 in c:\python\python311\lib\site-packages (from pmdarima) (1.3.2)
# Collecting Cython!=0.29.18,!=0.29.31,>=0.29 (from pmdarima)
#   Obtaining dependency information for Cython!=0.29.18,!=0.29.31,>=0.29 from https://files.pythonhosted.org/packages/60/d0/30f3ecd4dcafa87cd024a2687a6be7aa14f94d75c040192f8f8629ef8ad8/Cython-3.0.7-cp311-cp311-win_amd64.whl.metadata
#   Downloading Cython-3.0.7-cp311-cp311-win_amd64.whl.metadata (3.2 kB)
# Requirement already satisfied: numpy>=1.21.2 in c:\python\python311\lib\site-packages (from pmdarima) (1.25.1)
# Requirement already satisfied: pandas>=0.19 in c:\python\python311\lib\site-packages (from pmdarima) (2.0.3)
# Requirement already satisfied: scikit-learn>=0.22 in c:\python\python311\lib\site-packages (from pmdarima) (1.3.1)
# Requirement already satisfied: scipy>=1.3.2 in c:\python\python311\lib\site-packages (from pmdarima) (1.11.1)
# Requirement already satisfied: statsmodels>=0.13.2 in c:\python\python311\lib\site-packages (from pmdarima) (0.14.0)
# Requirement already satisfied: urllib3 in c:\python\python311\lib\site-packages (from pmdarima) (2.0.3)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in c:\python\python311\lib\site-packages (from pmdarima) (65.5.0)
# Requirement already satisfied: packaging>=17.1 in c:\python\python311\lib\site-packages (from pmdarima) (23.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\python\python311\lib\site-packages (from pandas>=0.19->pmdarima) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\python\python311\lib\site-packages (from pandas>=0.19->pmdarima) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in c:\python\python311\lib\site-packages (from pandas>=0.19->pmdarima) (2023.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\python\python311\lib\site-packages (from scikit-learn>=0.22->pmdarima) (3.2.0)
# Requirement already satisfied: patsy>=0.5.2 in c:\python\python311\lib\site-packages (from statsmodels>=0.13.2->pmdarima) (0.5.3)
# Requirement already satisfied: six in c:\python\python311\lib\site-packages (from patsy>=0.5.2->statsmodels>=0.13.2->pmdarima) (1.16.0)
# Downloading pmdarima-2.0.4-cp311-cp311-win_amd64.whl (614 kB)
#    ---------------------------------------- 0.0/614.7 kB ? eta -:--:--
#    --- ------------------------------------ 61.4/614.7 kB 1.7 MB/s eta 0:00:01
#    --------------- ------------------------ 245.8/614.7 kB 3.0 MB/s eta 0:00:01
#    ------------------------- -------------- 389.1/614.7 kB 3.0 MB/s eta 0:00:01
#    ---------------------------------------- 614.7/614.7 kB 3.9 MB/s eta 0:00:00
# Downloading Cython-3.0.7-cp311-cp311-win_amd64.whl (2.8 MB)
#    ---------------------------------------- 0.0/2.8 MB ? eta -:--:--
#    -------------------- ------------------- 1.4/2.8 MB 30.5 MB/s eta 0:00:01
#    ---------------------------------------  2.8/2.8 MB 35.4 MB/s eta 0:00:01
#    ---------------------------------------- 2.8/2.8 MB 25.2 MB/s eta 0:00:00
# Installing collected packages: Cython, pmdarima
# Successfully installed Cython-3.0.7 pmdarima-2.0.4
# [notice] A new release of pip is available: 23.2.1 -> 23.3.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Collecting pyPortfolioOpt
#   Downloading pyportfolioopt-1.5.5-py3-none-any.whl (61 kB)
#      ---------------------------------------- 0.0/61.9 kB ? eta -:--:--
#      ---------------------------------------  61.4/61.9 kB 1.7 MB/s eta 0:00:01
#      -------------------------------------- 61.9/61.9 kB 820.7 kB/s eta 0:00:00
# Collecting cvxpy<2.0.0,>=1.1.19 (from pyPortfolioOpt)
#   Obtaining dependency information for cvxpy<2.0.0,>=1.1.19 from https://files.pythonhosted.org/packages/fc/56/377e9412449a48340ee070eee16ed205b7c4170c36bd1b67345898da21e4/cvxpy-1.4.1-cp311-cp311-win_amd64.whl.metadata
#   Downloading cvxpy-1.4.1-cp311-cp311-win_amd64.whl.metadata (9.0 kB)
# Requirement already satisfied: numpy<2.0.0,>=1.22.4 in c:\python\python311\lib\site-packages (from pyPortfolioOpt) (1.25.1)
# Requirement already satisfied: pandas>=0.19 in c:\python\python311\lib\site-packages (from pyPortfolioOpt) (2.0.3)
# Requirement already satisfied: scipy<2.0,>=1.3 in c:\python\python311\lib\site-packages (from pyPortfolioOpt) (1.11.1)
# Collecting osqp>=0.6.2 (from cvxpy<2.0.0,>=1.1.19->pyPortfolioOpt)
#   Obtaining dependency information for osqp>=0.6.2 from https://files.pythonhosted.org/packages/23/46/232041be3d85624ec4c20b3bdb8bd4bfb6640851901db155917e0c412aef/osqp-0.6.3-cp311-cp311-win_amd64.whl.metadata
#   Downloading osqp-0.6.3-cp311-cp311-win_amd64.whl.metadata (1.8 kB)
# Collecting ecos>=2 (from cvxpy<2.0.0,>=1.1.19->pyPortfolioOpt)
#   Downloading ecos-2.0.12-cp311-cp311-win_amd64.whl (72 kB)
#      ---------------------------------------- 0.0/72.0 kB ? eta -:--:--
#      ---------------------------------------- 72.0/72.0 kB 4.1 MB/s eta 0:00:00
# Collecting clarabel>=0.5.0 (from cvxpy<2.0.0,>=1.1.19->pyPortfolioOpt)
#   Obtaining dependency information for clarabel>=0.5.0 from https://files.pythonhosted.org/packages/a8/6b/0f04f31c1528ab1f6bbc9e6ff83d019386941db4c9e0a7ddd7d16f5a85d2/clarabel-0.6.0-cp37-abi3-win_amd64.whl.metadata
#   Downloading clarabel-0.6.0-cp37-abi3-win_amd64.whl.metadata (4.4 kB)
# Collecting scs>=3.0 (from cvxpy<2.0.0,>=1.1.19->pyPortfolioOpt)
#   Obtaining dependency information for scs>=3.0 from https://files.pythonhosted.org/packages/27/57/38e633489613d0b72cfb40f9f04d2e45afd9754ef002f052e00ffca9f884/scs-3.2.4.post1-cp311-cp311-win_amd64.whl.metadata
#   Downloading scs-3.2.4.post1-cp311-cp311-win_amd64.whl.metadata (2.1 kB)
# Collecting pybind11 (from cvxpy<2.0.0,>=1.1.19->pyPortfolioOpt)
#   Obtaining dependency information for pybind11 from https://files.pythonhosted.org/packages/06/55/9f73c32dda93fa4f539fafa268f9504e83c489f460c380371d94296126cd/pybind11-2.11.1-py3-none-any.whl.metadata
#   Downloading pybind11-2.11.1-py3-none-any.whl.metadata (9.5 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\python\python311\lib\site-packages (from pandas>=0.19->pyPortfolioOpt) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\python\python311\lib\site-packages (from pandas>=0.19->pyPortfolioOpt) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in c:\python\python311\lib\site-packages (from pandas>=0.19->pyPortfolioOpt) (2023.3)
# Collecting qdldl (from osqp>=0.6.2->cvxpy<2.0.0,>=1.1.19->pyPortfolioOpt)
#   Obtaining dependency information for qdldl from https://files.pythonhosted.org/packages/f3/0c/972bd00b80aefc57c9a25ca47f802e315ce054fe72cd74d95af6c0f5b3f0/qdldl-0.1.7.post0-cp311-cp311-win_amd64.whl.metadata
#   Downloading qdldl-0.1.7.post0-cp311-cp311-win_amd64.whl.metadata (1.8 kB)
# Requirement already satisfied: six>=1.5 in c:\python\python311\lib\site-packages (from python-dateutil>=2.8.2->pandas>=0.19->pyPortfolioOpt) (1.16.0)
# Downloading cvxpy-1.4.1-cp311-cp311-win_amd64.whl (1.0 MB)
#    ---------------------------------------- 0.0/1.0 MB ? eta -:--:--
#    -- ------------------------------------- 0.1/1.0 MB ? eta -:--:--
#    -- ------------------------------------- 0.1/1.0 MB ? eta -:--:--
#    ---- ----------------------------------- 0.1/1.0 MB 1.3 MB/s eta 0:00:01
#    --------- ------------------------------ 0.2/1.0 MB 1.6 MB/s eta 0:00:01
#    ----------- ---------------------------- 0.3/1.0 MB 1.5 MB/s eta 0:00:01
#    --------------- ------------------------ 0.4/1.0 MB 1.7 MB/s eta 0:00:01
#    ---------------- ----------------------- 0.4/1.0 MB 1.7 MB/s eta 0:00:01
#    ---------------- ----------------------- 0.4/1.0 MB 1.7 MB/s eta 0:00:01
#    -------------------- ------------------- 0.5/1.0 MB 1.5 MB/s eta 0:00:01
#    -------------------- ------------------- 0.5/1.0 MB 1.5 MB/s eta 0:00:01
#    ------------------------- -------------- 0.7/1.0 MB 1.4 MB/s eta 0:00:01
#    ------------------------- -------------- 0.7/1.0 MB 1.4 MB/s eta 0:00:01
#    ------------------------- -------------- 0.7/1.0 MB 1.4 MB/s eta 0:00:01
#    ---------------------------- ----------- 0.7/1.0 MB 1.3 MB/s eta 0:00:01
#    ----------------------------- ---------- 0.8/1.0 MB 1.2 MB/s eta 0:00:01
#    ------------------------------- -------- 0.8/1.0 MB 1.2 MB/s eta 0:00:01
#    ------------------------------- -------- 0.8/1.0 MB 1.2 MB/s eta 0:00:01
#    ------------------------------- -------- 0.8/1.0 MB 1.2 MB/s eta 0:00:01
#    ----------------------------------- ---- 0.9/1.0 MB 1.2 MB/s eta 0:00:01
#    ------------------------------------- -- 1.0/1.0 MB 1.1 MB/s eta 0:00:01
#    ---------------------------------------  1.0/1.0 MB 1.2 MB/s eta 0:00:01
#    ---------------------------------------- 1.0/1.0 MB 1.2 MB/s eta 0:00:00
# Downloading clarabel-0.6.0-cp37-abi3-win_amd64.whl (355 kB)
#    ---------------------------------------- 0.0/355.1 kB ? eta -:--:--
#    ---------- ----------------------------- 92.2/355.1 kB 2.6 MB/s eta 0:00:01
#    --------------------- ------------------ 194.6/355.1 kB 2.4 MB/s eta 0:00:01
#    ---------------------------------- ----- 307.2/355.1 kB 2.4 MB/s eta 0:00:01
#    ---------------------------------------- 355.1/355.1 kB 2.0 MB/s eta 0:00:00
# Downloading osqp-0.6.3-cp311-cp311-win_amd64.whl (292 kB)
#    ---------------------------------------- 0.0/293.0 kB ? eta -:--:--
#    ----------- ---------------------------- 81.9/293.0 kB 2.3 MB/s eta 0:00:01
#    ---------------------- ----------------- 163.8/293.0 kB 2.0 MB/s eta 0:00:01
#    ---------------------------------- ----- 256.0/293.0 kB 2.0 MB/s eta 0:00:01
#    ---------------------------------------- 293.0/293.0 kB 2.0 MB/s eta 0:00:00
# Downloading scs-3.2.4.post1-cp311-cp311-win_amd64.whl (8.4 MB)
#    ---------------------------------------- 0.0/8.4 MB ? eta -:--:--
#     --------------------------------------- 0.1/8.4 MB 3.2 MB/s eta 0:00:03
#     --------------------------------------- 0.2/8.4 MB 2.5 MB/s eta 0:00:04
#    - -------------------------------------- 0.3/8.4 MB 2.7 MB/s eta 0:00:03
#    -- ------------------------------------- 0.4/8.4 MB 2.5 MB/s eta 0:00:04
#    -- ------------------------------------- 0.6/8.4 MB 2.5 MB/s eta 0:00:04
#    --- ------------------------------------ 0.7/8.4 MB 2.5 MB/s eta 0:00:04
#    --- ------------------------------------ 0.8/8.4 MB 2.5 MB/s eta 0:00:04
#    ---- ----------------------------------- 0.9/8.4 MB 2.5 MB/s eta 0:00:03
#    ----- ---------------------------------- 1.1/8.4 MB 2.6 MB/s eta 0:00:03
#    ----- ---------------------------------- 1.2/8.4 MB 2.6 MB/s eta 0:00:03
#    ------ --------------------------------- 1.3/8.4 MB 2.6 MB/s eta 0:00:03
#    ------- -------------------------------- 1.5/8.4 MB 2.6 MB/s eta 0:00:03
#    ------- -------------------------------- 1.6/8.4 MB 2.6 MB/s eta 0:00:03
#    -------- ------------------------------- 1.8/8.4 MB 2.7 MB/s eta 0:00:03
#    --------- ------------------------------ 1.9/8.4 MB 2.7 MB/s eta 0:00:03
#    --------- ------------------------------ 2.0/8.4 MB 2.7 MB/s eta 0:00:03
#    ---------- ----------------------------- 2.1/8.4 MB 2.7 MB/s eta 0:00:03
#    ---------- ----------------------------- 2.3/8.4 MB 2.7 MB/s eta 0:00:03
#    ----------- ---------------------------- 2.4/8.4 MB 2.7 MB/s eta 0:00:03
#    ----------- ---------------------------- 2.5/8.4 MB 2.8 MB/s eta 0:00:03
#    ------------ --------------------------- 2.7/8.4 MB 2.7 MB/s eta 0:00:03
#    ------------- -------------------------- 2.8/8.4 MB 2.8 MB/s eta 0:00:03
#    ------------- -------------------------- 2.9/8.4 MB 2.8 MB/s eta 0:00:02
#    -------------- ------------------------- 3.0/8.4 MB 2.7 MB/s eta 0:00:02
#    -------------- ------------------------- 3.1/8.4 MB 2.8 MB/s eta 0:00:02
#    --------------- ------------------------ 3.3/8.4 MB 2.8 MB/s eta 0:00:02
#    ---------------- ----------------------- 3.4/8.4 MB 2.8 MB/s eta 0:00:02
#    ---------------- ----------------------- 3.5/8.4 MB 2.8 MB/s eta 0:00:02
#    ----------------- ---------------------- 3.6/8.4 MB 2.8 MB/s eta 0:00:02
#    ----------------- ---------------------- 3.8/8.4 MB 2.8 MB/s eta 0:00:02
#    ------------------ --------------------- 4.0/8.4 MB 2.8 MB/s eta 0:00:02
#    ------------------- -------------------- 4.1/8.4 MB 2.8 MB/s eta 0:00:02
#    -------------------- ------------------- 4.2/8.4 MB 2.9 MB/s eta 0:00:02
#    -------------------- ------------------- 4.4/8.4 MB 2.9 MB/s eta 0:00:02
#    --------------------- ------------------ 4.5/8.4 MB 2.9 MB/s eta 0:00:02
#    ---------------------- ----------------- 4.7/8.4 MB 2.9 MB/s eta 0:00:02
#    ----------------------- ---------------- 4.8/8.4 MB 2.9 MB/s eta 0:00:02
#    ----------------------- ---------------- 5.0/8.4 MB 2.9 MB/s eta 0:00:02
#    ------------------------ --------------- 5.1/8.4 MB 3.0 MB/s eta 0:00:02
#    ------------------------- -------------- 5.3/8.4 MB 3.0 MB/s eta 0:00:02
#    -------------------------- ------------- 5.5/8.4 MB 3.0 MB/s eta 0:00:01
#    -------------------------- ------------- 5.6/8.4 MB 3.0 MB/s eta 0:00:01
#    --------------------------- ------------ 5.8/8.4 MB 3.0 MB/s eta 0:00:01
#    ---------------------------- ----------- 6.0/8.4 MB 3.0 MB/s eta 0:00:01
#    ----------------------------- ---------- 6.2/8.4 MB 3.0 MB/s eta 0:00:01
#    ------------------------------ --------- 6.3/8.4 MB 3.1 MB/s eta 0:00:01
#    ------------------------------ --------- 6.5/8.4 MB 3.1 MB/s eta 0:00:01
#    ------------------------------- -------- 6.6/8.4 MB 3.1 MB/s eta 0:00:01
#    -------------------------------- ------- 6.8/8.4 MB 3.1 MB/s eta 0:00:01
#    --------------------------------- ------ 6.9/8.4 MB 3.1 MB/s eta 0:00:01
#    --------------------------------- ------ 7.1/8.4 MB 3.1 MB/s eta 0:00:01
#    ---------------------------------- ----- 7.2/8.4 MB 3.1 MB/s eta 0:00:01
#    ----------------------------------- ---- 7.4/8.4 MB 3.2 MB/s eta 0:00:01
#    ----------------------------------- ---- 7.5/8.4 MB 3.1 MB/s eta 0:00:01
#    ------------------------------------ --- 7.7/8.4 MB 3.2 MB/s eta 0:00:01
#    ------------------------------------- -- 8.0/8.4 MB 3.2 MB/s eta 0:00:01
#    -------------------------------------- - 8.1/8.4 MB 3.2 MB/s eta 0:00:01
#    ---------------------------------------  8.3/8.4 MB 3.2 MB/s eta 0:00:01
#    ---------------------------------------  8.4/8.4 MB 3.2 MB/s eta 0:00:01
#    ---------------------------------------- 8.4/8.4 MB 3.2 MB/s eta 0:00:00
# Downloading pybind11-2.11.1-py3-none-any.whl (227 kB)
#    ---------------------------------------- 0.0/227.7 kB ? eta -:--:--
#    ----------------------------------- ---- 204.8/227.7 kB 4.2 MB/s eta 0:00:01
#    ---------------------------------------- 227.7/227.7 kB 3.5 MB/s eta 0:00:00
# Downloading qdldl-0.1.7.post0-cp311-cp311-win_amd64.whl (85 kB)
#    ---------------------------------------- 0.0/85.1 kB ? eta -:--:--
#    ---------------------------------------- 85.1/85.1 kB 4.7 MB/s eta 0:00:00
# Installing collected packages: pybind11, scs, qdldl, ecos, clarabel, osqp, cvxpy, pyPortfolioOpt
# Successfully installed clarabel-0.6.0 cvxpy-1.4.1 ecos-2.0.12 osqp-0.6.3 pyPortfolioOpt-1.5.5 pybind11-2.11.1 qdldl-0.1.7.post0 scs-3.2.4.post1
# [notice] A new release of pip is available: 23.2.1 -> 23.3.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pandas.tseries.offsets import MonthEnd
import quantstats as qs
from datetime import datetime
import seaborn as sns
import warnings
# %matplotlib inline
warnings.filterwarnings('ignore')
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.svm import SVC
from catboost import CatBoostClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
import xgboost as xgb
import lightgbm as lgb
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import TimeSeriesSplit
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, VotingClassifier
import pmdarima as pm
from pmdarima import model_selection
from pmdarima.model_selection import train_test_split
from pmdarima import ARIMA
from pmdarima import auto_arima
from sklearn.metrics import mean_squared_error
from pypfopt import expected_returns
from pypfopt.efficient_frontier import EfficientFrontier
from pypfopt import risk_models
# %%
import yfinance as yf  # Make sure to install yfinance: pip install yfinance

# Define the stock symbol (AAPL for Apple Inc.)
stock_symbol = TICKERS

# Define the date range for the last year
start_date = pd.to_datetime('2020-01-01')  # Adjust the start date as needed
end_date = pd.to_datetime('2023-01-01')    # End date is today's date

# Download the stock data using yfinance
df = yf.download(TICKERS, start=start_date, end=end_date)
df
# Out:
# [*********************100%***********************]  95 of 95 completed
#               Adj Close                                                        \
#                  ABB.NS       ACC.NS  ADANIENT.NS ADANIGREEN.NS ADANIPORTS.NS
# Date
# 2020-01-01  1261.449829  1339.945312   206.013153    174.750000    365.911530
# 2020-01-02  1265.557007  1389.212769   209.333527    183.449997    371.240601
# 2020-01-03  1292.986328  1373.627686   206.459167    192.600006    370.610779
# 2020-01-06  1258.516235  1335.711914   197.786484    200.600006    368.382294
# 2020-01-07  1277.829224  1354.739502   202.246719    210.600006    372.839264
# ...                 ...          ...          ...           ...           ...
# 2022-12-26  2716.792969  2399.084473  3714.894043   1876.849976    800.667358
# 2022-12-27  2734.741211  2452.883545  3767.767578   1908.699951    811.693237
# 2022-12-28  2716.494141  2430.463135  3795.803467   1897.849976    804.938599
# 2022-12-29  2676.459473  2423.039307  3808.697266   1910.250000    814.077209
# 2022-12-30  2675.263184  2416.852539  3856.423340   1931.800049    812.636841
#
#                                                                               \
#            AMBUJACEM.NS APOLLOHOSP.NS ASIANPAINT.NS      ATGL.NS AXISBANK.NS
# Date
# 2020-01-01   174.539413   1412.195923   1743.498413   176.206741  746.799988
# 2020-01-02   181.937393   1479.818359   1741.019287   179.295456  755.029114
# 2020-01-03   180.209702   1471.353149   1702.857056   173.865280  741.064636
# 2020-01-06   174.450790   1447.987305   1659.833496   162.706024  721.414612
# 2020-01-07   176.311371   1464.026489   1676.605469   170.477646  723.908264
# ...                 ...           ...           ...          ...         ...
# 2022-12-26   508.215729   4669.126953   3030.543213  3310.423828  927.753296
# 2022-12-27   517.260071   4629.004883   3086.621094  3351.607910  931.249695
# 2022-12-28   512.416687   4574.031250   3097.628418  3604.410645  923.757385
# 2022-12-29   516.716431   4510.035645   3089.149658  3791.538330  933.597290
# 2022-12-30   518.050842   4463.334961   3062.127197  3691.427002  932.798096
#
#             ...       Volume                                           \
#             ... TATASTEEL.NS   TCS.NS TECHM.NS TITAN.NS TORNTPHARM.NS
# Date        ...
# 2020-01-01  ...    121005300  1354908   746371  3137636         44954
# 2020-01-02  ...    216749610  2380752  1133488  3286436        173060
# 2020-01-03  ...    129568630  4655761  2121704  2695237       1008842
# 2020-01-06  ...     96016080  3023209  1734439  4494752        330866
# 2020-01-07  ...    131957880  2429317  1937143  2363578        266930
# ...         ...          ...      ...      ...      ...           ...
# 2022-12-26  ...     33995681   870157   966423  1076808        471591
# 2022-12-27  ...     76033410   835883  1615647   791283         91756
# 2022-12-28  ...     50660601   910795  1077963  2443430        418806
# 2022-12-29  ...     51751642  1037927  1977329  1583143        485039
# 2022-12-30  ...     56048485  1163131  1317151  1057182        326780
#
#
#            ULTRACEMCO.NS   UPL.NS   VBL.NS   VEDL.NS WIPRO.NS
# Date
# 2020-01-01        163949   720807   337954  14266524  1413866
# 2020-01-02       1458328  1388201   461718  17137897  1443966
# 2020-01-03        635983  1063950   409063  12108687  3381404
# 2020-01-06        462841  1218216   301743  11218355  4566695
# 2020-01-07        524372  4247207   514179  24417974  4402787
# ...                  ...      ...      ...       ...      ...
# 2022-12-26        328414   955078  2127586   7669940  3630574
# 2022-12-27        295144  1693081  1610880  11251874  3842920
# 2022-12-28        260015  3025343  1680516   5313187  3838001
# 2022-12-29        449116  1898772  2105538   6837877  4742699
# 2022-12-30        232317  1387568  1901588   6318160  4128278
#
# [747 rows x 570 columns]

# %%
df.isnull().sum()
# Out:
# Adj Close  ABB.NS           0
#            ACC.NS           0
#            ADANIENT.NS      0
#            ADANIGREEN.NS    0
#            ADANIPORTS.NS    0
#                            ..
# Volume     ULTRACEMCO.NS    0
#            UPL.NS           0
#            VBL.NS           0
#            VEDL.NS          0
#            WIPRO.NS         0
# Length: 570, dtype: int64

# %%
df['Close']['ABB.NS']
# Out:
# Date
# 2020-01-01    1290.000000
# 2020-01-02    1294.199951
# 2020-01-03    1322.250000
# 2020-01-06    1287.000000
# 2020-01-07    1306.750000
#                  ...
# 2022-12-26    2724.649902
# 2022-12-27    2742.649902
# 2022-12-28    2724.350098
# 2022-12-29    2684.199951
# 2022-12-30    2683.000000
# Name: ABB.NS, Length: 747, dtype: float64

# %%
df.columns
# Out:
# MultiIndex([('Adj Close',        'ABB.NS'),
#             ('Adj Close',        'ACC.NS'),
#             ('Adj Close',   'ADANIENT.NS'),
#             ('Adj Close', 'ADANIGREEN.NS'),
#             ('Adj Close', 'ADANIPORTS.NS'),
#             ('Adj Close',  'AMBUJACEM.NS'),
#             ('Adj Close', 'APOLLOHOSP.NS'),
#             ('Adj Close', 'ASIANPAINT.NS'),
#             ('Adj Close',       'ATGL.NS'),
#             ('Adj Close',   'AXISBANK.NS'),
#             ...
#             (   'Volume',  'TATASTEEL.NS'),
#             (   'Volume',        'TCS.NS'),
#             (   'Volume',      'TECHM.NS'),
#             (   'Volume',      'TITAN.NS'),
#             (   'Volume', 'TORNTPHARM.NS'),
#             (   'Volume', 'ULTRACEMCO.NS'),
#             (   'Volume',        'UPL.NS'),
#             (   'Volume',        'VBL.NS'),
#             (   'Volume',       'VEDL.NS'),
#             (   'Volume',      'WIPRO.NS')],
#            length=570)

# %%
start_date = pd.to_datetime('2020-01-01')
end_date = pd.to_datetime('2023-01-01')

data_1 = yf.download(TICKERS, start=start_date, end=end_date)
df = data_1["Close"]
df_1 = data_1["Open"]
df_2 = data_1["Volume"]
df_3 = data_1["Low"]
df_4 = data_1["High"]

common_multiplier = 1.5
initial_investment = 100
nav_gmv = pd.Series()

quarter_start_date = start_date
tscv = TimeSeriesSplit(n_splits=10)
quarter_start_date_2 = quarter_start_date + pd.DateOffset(months = 12)

df_11 = df[(df.index >= quarter_start_date_2) & (df.index < end_date)]

while quarter_start_date_2 < end_date:
    prev_quarter_start_date = quarter_start_date_2 - pd.DateOffset(months=3)
    prev_quarter_end_date = quarter_start_date_2 - pd.DateOffset(days=1)
    quarter_end_date = quarter_start_date_2 + pd.DateOffset(months=3)
    

    prev_quarter_data = df[(df.index >= prev_quarter_start_date) & (df.index < prev_quarter_end_date)]
    quarter_data = df[(df.index >= quarter_start_date_2) & (df.index < quarter_end_date)]
    prev_quarter_data_1 = df[(df.index >= start_date) & (df.index < prev_quarter_end_date)]
#     print(quarter_data)

    mnthly_rets = prev_quarter_data.pct_change().resample('M').agg(lambda x: (x + 1).prod() - 1)

    quarter_high_volatility_stocks = prev_quarter_data.std().nsmallest(30).index.tolist()
    quarter_momentum_stocks = mnthly_rets.iloc[-1].nlargest(30).index.tolist()


    quarter_high_volatility_stocks_set = set(quarter_high_volatility_stocks)
    quarter_momentum_stocks_set = set(quarter_momentum_stocks)

    common_stocks = quarter_high_volatility_stocks_set.intersection(quarter_momentum_stocks_set)
    common_stocks_list = list(common_stocks)

    combined_stocks = list(set(quarter_high_volatility_stocks + quarter_momentum_stocks))
    all_stocks = pd.DataFrame(index=combined_stocks)
    count = 0
    scores_list = []
    # Initialize base learners
    # rf_model = RandomForestClassifier(random_state=1)
    base_learner = SVC(probability=True,C=1, gamma=0.01, kernel='rbf', random_state=1)
    # adaboost_model = AdaBoostClassifier(base_estimator=DecisionTreeClassifier(random_state=1), n_estimators=50, learning_rate=1.0, random_state=1)
    # logistic_model = LogisticRegression(solver='saga', penalty='l1', random_state=1)
    rf_model = AdaBoostClassifier(base_estimator=base_learner, n_estimators=50, learning_rate=1.0, random_state=1)
# #     # adaboost_model = ExtraTreesClassifier(random_state=1)
    logistic_model =  CatBoostClassifier(random_state=1, verbose=0)

#     Create a stacking ensemble model
    ensemble_model = VotingClassifier(estimators=[
        ('rf', rf_model),
        ('logistic', logistic_model)], voting='soft')  # Use 'soft' for probability voting
    
    ml_start_date = quarter_start_date_2 - pd.DateOffset(months=9)
    ml_end_date = quarter_end_date - pd.DateOffset(days = 1)

    for stock in all_stocks.index:
      data_2 = pd.DataFrame()
      data_2['Close'] = df[stock]
      data_2['Open'] = df_1[stock]
      data_2['Volume'] = df_2[stock]
      data_2["Low"] = df_3[stock]
      data_2["High"] = df_4[stock]
      data = data_2[(data_2.index >= ml_start_date) & (data_2.index < ml_end_date)]
      data['returns'] = np.log(data['Close'] / data['Close'].shift(1))
      # Create target values
      data['target'] = np.where(data.returns.shift(-1) > 0, 1, 0)

      features_list = []
      # SD based features
      for i in range(5, 20, 5):
          col_name = 'std_' + str(i)
          data[col_name] = data['Close'].rolling(window=i).std()
          features_list.append(col_name)

      # MA based features
      for i in range(10, 30, 5):
          col_name = 'ma_' + str(i)
          data[col_name] = data['Close'].rolling(window=i).mean()
          features_list.append(col_name)

      # Daily pct change based features
      for i in range(3, 12, 3):
          col_name = 'pct_' + str(i)
          data[col_name] = data['Close'].pct_change().rolling(i).sum()
          features_list.append(col_name)

      # Feature based on volume
      col_name = 'vma_4'
      data[col_name] = data['Volume'].rolling(4).mean()
      features_list.append(col_name)

      # Intraday movement
      col_name = 'co'
      data[col_name] = data['Close'] - data['Open']
      features_list.append(col_name)

      # Bollinger Bands
      window = 20
      col_name_upper = 'bollinger_upper'
      col_name_lower = 'bollinger_lower'

      data['sma'] = data['Close'].rolling(window=window).mean()
      data['std'] = data['Close'].rolling(window=window).std()

      data[col_name_upper] = data['sma'] + 2 * data['std']
      data[col_name_lower] = data['sma'] - 2 * data['std']

      features_list += [col_name_upper, col_name_lower]

      # ADX indicator
      col_name = 'adx_14'
      window_atr = 14  # You can adjust this window size as needed
      data['tr'] = np.maximum.reduce([data['High'] - data['Low'],
                                      np.abs(data['High'] - data['Close'].shift(1)),
                                      np.abs(data['Low'] - data['Close'].shift(1))])
      data[col_name] = data['tr'].rolling(window=window_atr).mean()
      features_list += [col_name]

      # # Support/Resistance Levels
      # data['support'] = ta.momentum.support(data['Close'])
      # data['resistance'] = ta.momentum.resistance(data['Close'])
      # features_list += ['support', 'resistance']


      data.dropna(inplace=True)
      for train_index, test_index in tscv.split(data.index):
          # Split the data into training and testing sets using the time series cross-validator
          X_train = data[features_list].iloc[train_index]
          y_train = data.iloc[train_index]['target']
          X_test = data[features_list].iloc[test_index]
          y_test = data.iloc[test_index]['target']

      data[features_list + ['target']]
#       X_train , X_test, y_train, y_test = train_test_split(data[features_list].iloc[:-1],
#                                                     data.iloc[:-1]['target'],
#                                                     test_size= 0.25,
#                                                     shuffle=False)

      X_train.shape, y_train.shape, X_test.shape, y_test.shape
      scaler = StandardScaler()

      X_train_scaled = scaler.fit_transform(X_train)
      X_test_scaled = scaler.transform(X_test)
      X_train_scaled_df = pd.DataFrame(X_train_scaled, columns=X_train.columns)
#       df_10 = data['Close']
#       train, test = train_test_split(df_10, test_size=0.25)
#       orders = [(2, 1, 2), (1, 1, 2), (1, 1, 1), (2, 2, 1)]     
#       seasonal_orders = [(1, 1, 1, 12), (0, 1, 0, 12), (0, 1, 1, 12), (1, 2, 1, 12),(0, 2, 1, 12), (1, 1, 0, 12), (2, 1, 1, 12), (1, 2, 0, 12)]
#       best_mse = np.inf
#       best_order = None
#       best_seasonal_order = None
      # param_dist = {
      #     'n_estimators': [50, 100, 200, 300],
      #     'max_features': ['auto', 'sqrt', 'log2'],
      #     'max_depth': [None, 10, 20, 30, 40, 50],
      #     'min_samples_split': [2, 5, 10],
      #     'min_samples_leaf': [1, 2, 4]
      # }

#       model = LogisticRegression(solver='saga', penalty = 'l1', random_state=1)
      # model = SVC(C=1, gamma=0.01, kernel='rbf', random_state=1)
      # base_learner = SVC(probability=True,C=1, gamma=0.01, kernel='rbf', random_state=1)
#       model = GaussianNB()
#       model = DecisionTreeClassifier(criterion = 'entropy', min_samples_leaf = 2, min_samples_split = 10, random_state=1)
#       model = RandomForestClassifier(n_estimators = 20, min_samples_split = 10, min_samples_leaf = 1, max_depth = 40, random_state=1)
      # model = CatBoostClassifier(random_state=1, verbose=0)
#       model = xgb.XGBClassifier(random_state=1)
      # model = lgb.LGBMClassifier(random_state=1)
#       model = ExtraTreesClassifier(random_state=1)
      # model = GradientBoostingClassifier(random_state=1)
#       model = AdaBoostClassifier(base_estimator=base_learner, n_estimators=50, learning_rate=1.0, random_state=1)
      # param_grid = {'C': [0.1, 1, 10, 100], 'gamma': [0.01, 0.1, 1, 'scale', 'auto'], 'kernel': ['linear', 'rbf', 'sigmoid','poly']}
      # # grid_search = GridSearchCV(svm_model, param_grid, cv=5, scoring='accuracy')
      # random_search = RandomizedSearchCV(model, param_distributions=param_dist, n_iter=10, cv=5, scoring='accuracy', random_state=1)
#       for order in orders:
#             for seasonal_order in seasonal_orders:
#                 model = pm.ARIMA(order=order, seasonal_order=seasonal_order, suppress_warnings=True)
#                 model.fit(train)
#                 y_pred = model.predict(len(test))
#                 mse = mean_squared_error(test, y_pred)
            
#                 # Update best hyperparameters if the current combination is better
#                 if mse < best_mse:
#                     best_mse = mse
#                     best_order = order
#                     best_seasonal_order = seasonal_order
                  
#       print(best_order)
#       print(best_seasonal_order)

# # Train the final model with the best hyperparameters
#       final_model = pm.ARIMA(order=best_order, seasonal_order=best_seasonal_order, suppress_warnings=True)
#       final_model.fit(train)

# # Make predictions on the test set
#       y_pred = final_model.predict(len(test))

#       model = ARIMA(order = arima_params['order'],suppress_warnings=True)
#       grid_search = pm.model_selection.GridSearchCV(model, param_grid=arima_params, scoring='mean_squared_error', cv=cv)
#       grid_search.fit(train)
    
#        # Get the best hyperparameters
#       best_params = grid_search.best_params_
        
        
#       model = pm.ARIMA(order=(1,1,2), suppress_warnings=True)
        
#       model.fit(train)

#       y_pred_train = model.predict(n_periods = len(train))
#       y_pred = model.predict(n_periods = len(test))
#       total_data_length = len(data)
      
#       cv = model_selection.SlidingWindowForecastCV(window_size=7, step=1, h=1)

#       # Get the best hyperparameters
#       best_params = random_search.best_params_

#       # Train Random Forest model with the best hyperparameters
#       best_model = RandomForestClassifier(**best_params, random_state=1)
#       best_model.fit(X_train_scaled, y_train)

#       # Predictions
#       y_pred_train = best_model.predict(X_train_scaled)
#       y_pred = best_model.predict(X_test_scaled)
#       # Fit the model with the best hyperparameters
#       grid_search.fit(X_train_scaled, y_train)

#       # Get the best hyperparameters
#       best_params = grid_search.best_params_

#       Train SVM model with the best hyperparameters
#       best_model = SVC(**best_params, random_state=1)
#       best_model.fit(X_train_scaled, y_train)

#       Predictions
#       y_pred_train = best_model.predict(X_train_scaled)
#       y_pred = best_model.predict(X_test_scaled)
#       model.fit(X_train_scaled, y_train)
#       y_pred_train = model.predict(X_train_scaled) 
#       y_pred = model.predict(X_test_scaled)
    
      ensemble_model.fit(X_train_scaled, y_train)
      y_pred_train = ensemble_model.predict(X_train_scaled)
      y_pred = ensemble_model.predict(X_test_scaled)
        
#       model.fit(X_train_scaled, y_train)
#       y_pred_train = model.predict(X_train_scaled)
#       y_pred = model.predict(X_test_scaled)
        
#       model_cv_scores = model_selection.cross_val_score(model,train, scoring='mean_squared_error', cv=cv, verbose=2)
#       m2_average_error = np.average(model_cv_scores)
# #       count = count + 1
#       scores_list.append({'Stock': stock, 'Validation Score':m2_average_error})
      scores_list.append({'Stock': stock, 'Train Score': accuracy_score(y_train, y_pred_train), 'Test Score': accuracy_score(y_test, y_pred)})
#       # print('Model accuracy on training data:', accuracy_score(y_train, y_pred_train))
#       # print('Model accuracy on testing data:', accuracy_score(y_test, y_pred))
#       # print(count)
    # print(scores_list)
    print(len(scores_list))

    scores_df = pd.DataFrame(scores_list)
#     scores_df_1 = scores_df.sort_values(by='Validation Score').head(15)
    scores_df_1 = scores_df[scores_df['Test Score']>0.55].copy()
    
    a_list = []
    for stocks in scores_df_1['Stock']:
        a_list.append(prev_quarter_data_1[stocks])
    b= pd.DataFrame(a_list)
    b = b.T
    
    S = risk_models.CovarianceShrinkage(b).ledoit_wolf()    
    mu = expected_returns.capm_return(b)
    ef = EfficientFrontier(mu, S)
    weights = ef.max_sharpe()
    cleaned_weights = ef.clean_weights()
    scores_df_1['Weight'] = list(cleaned_weights.values())
    print(scores_df_1)
    
# Calculate the daily portfolio values
    for date in quarter_data.index:
        returns = df_11.pct_change()
        quart_returns = returns.loc[:date, scores_df_1['Stock']]
        quart_weights = scores_df_1['Weight'].values
        portfolio_daily_ret = (1 + quart_returns @ quart_weights).cumprod()
        portfolio_value = (initial_investment * portfolio_daily_ret[-1]).round(2)

        # Append daily portfolio value to the series
        nav_gmv = pd.concat([nav_gmv, pd.Series(portfolio_value, index=[date])])

        # Print or use the portfolio values as needed
        print(f" {date}: {portfolio_value}")

    quarter_start_date_2 = quarter_start_date_2 + pd.DateOffset(months=3)
# Out:
# [*********************100%***********************]  95 of 95 completed
# 52
#            Stock  Train Score  Test Score   Weight
# 1       DMART.NS     0.995098        0.60  0.04608
# 3         UPL.NS     0.980392        0.60  0.04962
# 5    GODREJCP.NS     1.000000        0.60  0.04770
# 8       TECHM.NS     0.965686        0.60  0.04887
# 10       BPCL.NS     1.000000        0.60  0.04908
# 11     INDIGO.NS     0.995098        0.60  0.04650
# 12  ICICIBANK.NS     0.960784        0.70  0.04978
# 13       NTPC.NS     0.995098        0.60  0.04598
# 18    PAGEIND.NS     0.990196        0.65  0.04539
# 21   JSWSTEEL.NS     0.941176        0.65  0.05067
# 29    HCLTECH.NS     0.995098        0.65  0.04755
# 31  AMBUJACEM.NS     0.985294        0.70  0.04619
# 33         LT.NS     0.985294        0.75  0.04841
# 34       VEDL.NS     0.965686        0.60  0.05050
# 36      DABUR.NS     1.000000        0.60  0.04428
# 37        VBL.NS     0.995098        0.60  0.04588
# 39      WIPRO.NS     0.995098        0.65  0.04690
# 42       INFY.NS     0.995098        0.65  0.04704
# 43        ITC.NS     0.995098        0.70  0.04665
# 45  COALINDIA.NS     1.000000        0.70  0.04705
# 50  MOTHERSON.NS     0.985294        0.60  0.04991
#  2021-01-01 00:00:00: nan
#  2021-01-04 00:00:00: 102.16
#  2021-01-05 00:00:00: 102.24
#  2021-01-06 00:00:00: 102.33
#  2021-01-07 00:00:00: 102.73
#  2021-01-08 00:00:00: 104.72
#  2021-01-11 00:00:00: 105.57
#  2021-01-12 00:00:00: 105.85
#  2021-01-13 00:00:00: 105.58
#  2021-01-14 00:00:00: 105.7
#  2021-01-15 00:00:00: 103.97
#  2021-01-18 00:00:00: 102.51
#  2021-01-19 00:00:00: 103.82
#  2021-01-20 00:00:00: 104.76
#  2021-01-21 00:00:00: 103.78
#  2021-01-22 00:00:00: 102.66
#  2021-01-25 00:00:00: 101.86
#  2021-01-27 00:00:00: 101.14
#  2021-01-28 00:00:00: 100.22
#  2021-01-29 00:00:00: 98.28
#  2021-02-01 00:00:00: 101.75
#  2021-02-02 00:00:00: 103.86
# 41       WIPRO.NS     1.000000        0.70  0.11091
#  2022-10-03 00:00:00: 149.54
#  2022-10-04 00:00:00: 152.57
#  2022-10-06 00:00:00: 154.02
#  2022-10-07 00:00:00: 153.1
#  2022-10-10 00:00:00: 152.68
#  2022-10-11 00:00:00: 150.14
#  2022-10-12 00:00:00: 151.08
#  2022-10-13 00:00:00: 150.66
#  2022-10-14 00:00:00: 150.26
#  2022-10-17 00:00:00: 149.71
#  2022-10-18 00:00:00: 151.17
#  2022-10-19 00:00:00: 150.2
#  2022-10-20 00:00:00: 152.22
#  2022-10-21 00:00:00: 152.44
#  2022-10-24 00:00:00: 152.49
#  2022-10-25 00:00:00: 151.68
#  2022-10-27 00:00:00: 152.8
#  2022-10-28 00:00:00: 152.46
#  2022-10-31 00:00:00: 153.5
#  2022-11-01 00:00:00: 156.38
#  2022-11-02 00:00:00: 156.6
#  2022-11-03 00:00:00: 157.09
#  2022-11-04 00:00:00: 159.28
#  2022-11-07 00:00:00: 158.88
#  2022-11-09 00:00:00: 158.56
#  2022-11-10 00:00:00: 157.43
#  2022-11-11 00:00:00: 159.85
#  2022-11-14 00:00:00: 159.98
#  2022-11-15 00:00:00: 160.43
#  2022-11-16 00:00:00: 159.12
#  2022-11-17 00:00:00: 158.25
#  2022-11-18 00:00:00: 158.54
#  2022-11-21 00:00:00: 158.48
#  2022-11-22 00:00:00: 159.07
#  2022-11-23 00:00:00: 158.87
#  2022-11-24 00:00:00: 161.63
#  2022-11-25 00:00:00: 162.91
#  2022-11-28 00:00:00: 163.29
#  2022-11-29 00:00:00: 164.09
#  2022-11-30 00:00:00: 165.46
#  2022-12-01 00:00:00: 166.01
#  2022-12-02 00:00:00: 165.76
#  2022-12-05 00:00:00: 165.51
#  2022-12-06 00:00:00: 165.12
#  2022-12-07 00:00:00: 164.92
#  2022-12-08 00:00:00: 164.7
#  2022-12-09 00:00:00: 163.23
#  2022-12-12 00:00:00: 164.26
#  2022-12-13 00:00:00: 165.06
#  2022-12-14 00:00:00: 165.3
#  2022-12-15 00:00:00: 164.1
#  2022-12-16 00:00:00: 162.71
#  2022-12-19 00:00:00: 164.37
#  2022-12-20 00:00:00: 163.78
#  2022-12-21 00:00:00: 161.27
#  2022-12-22 00:00:00: 160.25
#  2022-12-23 00:00:00: 155.87
#  2022-12-26 00:00:00: 157.54
#  2022-12-27 00:00:00: 159.2
#  2022-12-28 00:00:00: 158.87
#  2022-12-29 00:00:00: 159.13
#  2022-12-30 00:00:00: 159.33

# %%
# Remove duplicates from nav_gmv Series
nav_gmv = nav_gmv[~nav_gmv.index.duplicated()]

# %%
nav_df = pd.Series(nav_gmv)

# %%
nav_df
# Out:
# 2021-01-01       NaN
# 2021-01-04    102.16
# 2021-01-05    102.24
# 2021-01-06    102.33
# 2021-01-07    102.73
#                ...
# 2022-12-26    157.54
# 2022-12-27    159.20
# 2022-12-28    158.87
# 2022-12-29    159.13
# 2022-12-30    159.33
# Length: 496, dtype: float64

# %%
qs.reports.html(nav_df,"^NSEI")
# Out:
# [*********************100%***********************]  1 of 1 completed
# <script> var bl=new Blob(['<!-- generated by QuantStats for Python --><!DOCTYPE html><html lang="en"><head> <meta charset="utf-8"> <meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1"> <meta name="viewport" content="width=device-width, initial-scale=1, shrink-to-fit=no"> <title>Tearsheet (generated by QuantStats)</title> <meta name="robots" content="noindex, nofollow"> <link rel="shortcut icon" href="https://qtpylib.io/favicon.ico" type="image/x-icon"> <style> body{-webkit-font-smoothing:antialiased;-moz-osx-font-smoothing:grayscale;margin:30px}body,p,table,td,th{font:13px/1.4 Arial,sans-serif}.container{max-width:960px;margin:auto}img,svg{width:100%}h1,h2,h3,h4{font-weight:400;margin:0}h1 dt{display:inline;margin-left:10px;font-size:14px}h3{margin-bottom:10px;font-weight:700}h4{color:grey}h4 a{color:#09c;text-decoration:none}h4 a:hover{color:#069;text-decoration:underline}hr{margin:25px 0 40px;height:0;border:0;border-top:1px solid #ccc}#left{width:620px;margin-right:18px;margin-top:-1.2rem;float:left}#right{width:320px;float:right}#left svg{margin:-1.5rem 0}#monthly_heatmap{overflow:hidden}#monthly_heatmap svg{margin:-1.5rem 0}table{margin:0 0 40px;border:0;border-spacing:0;width:100%}table td,table th{text-align:right;padding:4px 5px 3px 5px}table th{text-align:right;padding:6px 5px 5px 5px}table td:first-of-type,table th:first-of-type{text-align:left;padding-left:2px}table td:last-of-type,table th:last-of-type{text-align:right;padding-right:2px}td hr{margin:5px 0}table th{font-weight:400}table thead th{font-weight:700;background:#eee}#eoy table td:after{content:"%"}#eoy table td:first-of-type:after,#eoy table td:last-of-type:after,#eoy table td:nth-of-type(4):after{content:""}#eoy table th{text-align:right}#eoy table th:first-of-type{text-align:left}#eoy table td:after{content:"%"}#eoy table td:first-of-type:after,#eoy table td:last-of-type:after{content:""}#ddinfo table td:nth-of-type(3):after{content:"%"}#ddinfo table th{text-align:right}#ddinfo table td:first-of-type,#ddinfo table td:nth-of-type(2),#ddinfo table th:first-of-type,#ddinfo table th:nth-of-type(2){text-align:left}#ddinfo table td:nth-of-type(3):after{content:"%"} @media print{hr{margin:25px 0}body{margin:0}.container{max-width:100%;margin:0}#left{width:55%;margin:0}#left svg{margin:0 0 -10%}#left svg:first-of-type{margin-top:-30%}#right{margin:0;width:45%}} </style></head><body onload="save()"> <div class="container"> <h1>Strategy Tearsheet <dt> 5 Jan, 2021 - 30 Dec, 2022</dt></h1> <h4>Benchmark is ^NSEI | Generated by <a href="http://quantstats.io" target="quantstats">QuantStats</a> (v. 0.0.62)</h4> <hr> <div id="left"> <div> <?xml version="1.0" encoding="utf-8" standalone="no"?><!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN" "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd"><svg xmlns:xlink="http://www.w3.org/1999/xlink" width="576pt" height="360pt" viewBox="0 0 576 360" xmlns="http://www.w3.org/2000/svg" version="1.1"> <metadata> <rdf:RDF xmlns:dc="http://purl.org/dc/elements/1.1/" xmlns:cc="http://creativecommons.org/ns#" xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#"> <cc:Work> <dc:type rdf:resource="http://purl.org/dc/dcmitype/StillImage"/> <dc:date>2023-12-20T22:04:40.820322</dc:date> <dc:format>image/svg+xml</dc:format> <dc:creator> <cc:Agent> <dc:title>Matplotlib v3.7.2, https://matplotlib.org/</dc:title> </cc:Agent> </dc:creator> </cc:Work> </rdf:RDF> </metadata> <defs> <style type="text/css">*{stroke-linejoin: round; stroke-linecap: butt}</style> </defs> <g id="figure_1"> <g id="patch_1"> <path d="M 0 360 L 576 360 L 576 0 L 0 0 z" style="fill: #ffffff"/> </g> <g id="axes_1"> <g id="patch_2"> <path d="M 44.6 308.650464 L 563.04 308.650464 L 563.04 38.88 L 44.6 38.88 z" style="fill: #ffffff"/> </g> <g id="matplotlib.axis_1"> <g id="xtick_1"> <g id="line2d_1"> <path d="M 65.561537 308.650464 L 65.561537 38.88 " clip-path="url(#p4fb934ff8b)" style="fill: none; stroke: #ffffff; stroke-linecap: round"/> </g> <g id="text_1"> <!-- 2021 ...

# %%
qs.reports.html(nav_df,"0P00009JAQ.BO")
# Out:
# [*********************100%***********************]  1 of 1 completed
# <script> var bl=new Blob(['<!-- generated by QuantStats for Python --><!DOCTYPE html><html lang="en"><head> <meta charset="utf-8"> <meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1"> <meta name="viewport" content="width=device-width, initial-scale=1, shrink-to-fit=no"> <title>Tearsheet (generated by QuantStats)</title> <meta name="robots" content="noindex, nofollow"> <link rel="shortcut icon" href="https://qtpylib.io/favicon.ico" type="image/x-icon"> <style> body{-webkit-font-smoothing:antialiased;-moz-osx-font-smoothing:grayscale;margin:30px}body,p,table,td,th{font:13px/1.4 Arial,sans-serif}.container{max-width:960px;margin:auto}img,svg{width:100%}h1,h2,h3,h4{font-weight:400;margin:0}h1 dt{display:inline;margin-left:10px;font-size:14px}h3{margin-bottom:10px;font-weight:700}h4{color:grey}h4 a{color:#09c;text-decoration:none}h4 a:hover{color:#069;text-decoration:underline}hr{margin:25px 0 40px;height:0;border:0;border-top:1px solid #ccc}#left{width:620px;margin-right:18px;margin-top:-1.2rem;float:left}#right{width:320px;float:right}#left svg{margin:-1.5rem 0}#monthly_heatmap{overflow:hidden}#monthly_heatmap svg{margin:-1.5rem 0}table{margin:0 0 40px;border:0;border-spacing:0;width:100%}table td,table th{text-align:right;padding:4px 5px 3px 5px}table th{text-align:right;padding:6px 5px 5px 5px}table td:first-of-type,table th:first-of-type{text-align:left;padding-left:2px}table td:last-of-type,table th:last-of-type{text-align:right;padding-right:2px}td hr{margin:5px 0}table th{font-weight:400}table thead th{font-weight:700;background:#eee}#eoy table td:after{content:"%"}#eoy table td:first-of-type:after,#eoy table td:last-of-type:after,#eoy table td:nth-of-type(4):after{content:""}#eoy table th{text-align:right}#eoy table th:first-of-type{text-align:left}#eoy table td:after{content:"%"}#eoy table td:first-of-type:after,#eoy table td:last-of-type:after{content:""}#ddinfo table td:nth-of-type(3):after{content:"%"}#ddinfo table th{text-align:right}#ddinfo table td:first-of-type,#ddinfo table td:nth-of-type(2),#ddinfo table th:first-of-type,#ddinfo table th:nth-of-type(2){text-align:left}#ddinfo table td:nth-of-type(3):after{content:"%"} @media print{hr{margin:25px 0}body{margin:0}.container{max-width:100%;margin:0}#left{width:55%;margin:0}#left svg{margin:0 0 -10%}#left svg:first-of-type{margin-top:-30%}#right{margin:0;width:45%}} </style></head><body onload="save()"> <div class="container"> <h1>Strategy Tearsheet <dt> 5 Jan, 2021 - 30 Dec, 2022</dt></h1> <h4>Benchmark is 0P00009JAQ.BO | Generated by <a href="http://quantstats.io" target="quantstats">QuantStats</a> (v. 0.0.62)</h4> <hr> <div id="left"> <div> <?xml version="1.0" encoding="utf-8" standalone="no"?><!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN" "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd"><svg xmlns:xlink="http://www.w3.org/1999/xlink" width="576pt" height="360pt" viewBox="0 0 576 360" xmlns="http://www.w3.org/2000/svg" version="1.1"> <metadata> <rdf:RDF xmlns:dc="http://purl.org/dc/elements/1.1/" xmlns:cc="http://creativecommons.org/ns#" xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#"> <cc:Work> <dc:type rdf:resource="http://purl.org/dc/dcmitype/StillImage"/> <dc:date>2023-12-20T22:10:34.849882</dc:date> <dc:format>image/svg+xml</dc:format> <dc:creator> <cc:Agent> <dc:title>Matplotlib v3.7.2, https://matplotlib.org/</dc:title> </cc:Agent> </dc:creator> </cc:Work> </rdf:RDF> </metadata> <defs> <style type="text/css">*{stroke-linejoin: round; stroke-linecap: butt}</style> </defs> <g id="figure_1"> <g id="patch_1"> <path d="M 0 360 L 576 360 L 576 0 L 0 0 z" style="fill: #ffffff"/> </g> <g id="axes_1"> <g id="patch_2"> <path d="M 44.6 308.650464 L 563.04 308.650464 L 563.04 38.88 L 44.6 38.88 z" style="fill: #ffffff"/> </g> <g id="matplotlib.axis_1"> <g id="xtick_1"> <g id="line2d_1"> <path d="M 65.561537 308.650464 L 65.561537 38.88 " clip-path="url(#pc7ac22801d)" style="fill: none; stroke: #ffffff; stroke-linecap: round"/> </g> <g id="text_1"> < ...
